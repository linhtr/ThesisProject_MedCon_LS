# %% [markdown]
# # Building dictionary frequency
#
# This code comes from Erick Velazquez.
#
# It builds a counter dictionary with the raw frequency of the tokens and lemmas from text documents. Before executing this code, first run this script: TreetaggerAnnotation_Wiki_MedCon.py

# %%
import mysql.connector
import requests
import json
import time
import argparse
import logging
import sys
import pandas as pd
from collections import Counter
import pickle
from tqdm import tqdm

# %%
punctuationMars = [',','.',';',':','(','-',')','{','}','[',']','\\','/','!','?','<','>','"']
def getTokensStrings(stringAnnotated):
    tokens = [] 
    POS = [] 
    lemmas  = []
    for line in str(stringAnnotated).split('\n'):
        #print(line)
        line = line.lower()
        s = line.split('\t')
        if s[0] not in punctuationMars and len(s)==3:
            tokens.append(s[0])
            POS.append(s[1])
            lemmas.append(s[2])
            
        #print(s.split('\t'))
    return tokens,POS,lemmas

# %%
annotated_data = pd.read_csv('Wiki_MedCon_TreetaggerAnnotation.csv', sep=";")
annotated_data
# Out:
#                                         title_annotated  \
# 0                                   Autism\tNN1\tautism
# 1     Motor\tNN1\tmotor\nneuron\tNN1\tneuron\ndiseas...
# 2     Acute\tAJ0\tacute\ndisseminated\tAJ0\tdissemin...
# 3                                   Ataxia\tNN1\tataxia
# 4                                 Abscess\tNN1\tabscess
# ...                                                 ...
# 8672  Galactose\tVVB\tgalactose\nepimerase\tNN1\tepi...
# 8673  Little\tAJ0\tlittle\nLeague\tNN1\tleague\nelbo...
# 8674  Penetrating\tAJ0\tpenetrating|penetrate\ntraum...
# 8675                  Camptodactyly\tNP0\tCamptodactyly
# 8676  Hepatosplenic\tAJ0\tHepatosplenic\nT-cell\tNN1...
#
#                                          text_annotated
# 0     Autism\tNN1\tautism\nis\tVBZ\tbe\na\tAT0\ta\nd...
# 1     Motor\tNN1\tmotor\nneuron\tNN1\tneuron\ndiseas...
# 2     Acute\tAJ0\tacute\ndisseminated\tAJ0\tdissemin...
# 3     Ataxia\tNN1\tataxia\nis\tVBZ\tbe\na\tAT0\ta\nn...
# 4     An\tAT0\tan\nabscess\tNN1\tabscess\nis\tVBZ\tb...
# ...                                                 ...
# 8672  Galactose\tVVB\tgalactose\nepimerase\tNN1\tepi...
# 8673  Little\tAJ0\tlittle\nLeague\tNN1\tleague\nelbo...
# 8674  Penetrating\tAJ0\tpenetrating|penetrate\ntraum...
# 8675  Camptodactyly\tNP0\tCamptodactyly\nis\tVBZ\tbe...
# 8676  Hepatosplenic\tAJ0\tHepatosplenic\nT-cell\tNN1...
#
# [8677 rows x 2 columns]

# %%
annotated_data.text_annotated[6482] #6461 #6482
# Out:
# 'Umbilical-urachal\tAJ0\tUmbilical-urachal\nsinus\tNN1\tsinus\nis\tVBZ\tbe\na\tAT0\ta\ncongenital\tAJ0\tcongenital\ndisorder\tNN1\tdisorder\nof\tPRF\tof\nthe\tAT0\tthe\nurinary\tAJ0\turinary\nbladder\tNN1\tbladder\ncaused\tVVN\tcause\nby\tPRP\tby\nfailure\tNN1\tfailure\nof\tPRF\tof\nobliteration\tNN1\tobliteration\nof\tPRF\tof\nproximal\tAJ0\tproximal\nor\tCJC\tor\ndistal\tAJ0\tdistal\npart\tNN1\tpart\nof\tPRF\tof\nthe\tAT0\tthe\nallantois\tNN1\tallantois\n,\tPUN\t,\nand\tCJC\tand\nthe\tAT0\tthe\npresentation\tNN1\tpresentation\nof\tPRF\tof\nthis\tDT0\tthis\nanomaly\tNN1\tanomaly\nis\tVBZ\tbe\nmore\tAV0\tmore\ncommon\tAJ0\tcommon\nin\tPRP\tin\nchildren\tNN2\tchild\nand\tCJC\tand\nrarer\tAJC\trare\nin\tPRP\tin\nadults\tNN2\tadult\n.\tSENT\t.\nIt\tPNP\tit\nis\tVBZ\tbe\nthought\tVVN\tthink\nhave\tVHB\thave\nbeen\tVBN\tbe\nfirst\tORD\tfirst\ndescribed\tVVN\tdescribe|described\nby\tPRP\tby\nCabriolus\tNP0\tCabriolus\nin\tPRP\tin\n1550.\tCRD\t@ord@\nInfection\tNN1\tinfection\n,\tPUN\t,\nwith\tPRP\twith\npossible\tAJ0\tpossible\nabscess\tNN1\tabscess\nformation\tNN1\tformation\n.\tSENT\t.\nConcurrent\tAJ0\tconcurrent\noccurrence\tNN1\toccurrence\nof\tPRF\tof\na\tAT0\ta\ntumour\tNN1\ttumour\n.\tSENT\t.\nurachus\tNN1\turachus'

# %%
couter_tokens = Counter()
counter_lemmas = Counter()
counter_pos = Counter()

# with open('Wiki_MedCon_TreetaggerAnnotation.csv') as f:
# for chunk in annotated_data:
#         display(chunk)
title = annotated_data['title_annotated'].to_list()
text = annotated_data['text_annotated'].to_list()

for ti in tqdm(title):
    to,po,le = getTokensStrings(ti)
    couter_tokens.update(to)
    counter_pos.update(po)
    counter_lemmas.update(le)

for te in tqdm(text):
    to,po,le = getTokensStrings(te)
    couter_tokens.update(to)
    counter_pos.update(po)
    counter_lemmas.update(le)

pickle.dump(couter_tokens, open("counter_Tokens.p", "wb"))
pickle.dump(counter_pos, open("counter_POS.p", "wb"))
pickle.dump(counter_lemmas, open("counter_Lemmas.p", "wb"))
# Out:
# 100%|██████████| 8677/8677 [00:00<00:00, 94808.82it/s]
# 100%|██████████| 8677/8677 [00:11<00:00, 761.50it/s]

# %%
print(len(couter_tokens))
couter_tokens.most_common()
# Out:
# 166557
# [('the', 471282),
#  ('of', 339325),
#  ('and', 246131),
#  ('in', 213046),
#  ('to', 193973),
#  ('a', 177881),
#  ('is', 165293),
#  ('with', 96718),
#  ('or', 87206),
#  ('as', 77064),
#  ('are', 74482),
#  ('be', 70263),
#  ('that', 66381),
#  ('for', 66162),
#  ('by', 54350),
#  ('may', 51461),
#  ('it', 47210),
#  ('can', 44736),
#  ('an', 40650),
#  ('this', 39477),
#  ('have', 38132),
#  ('on', 37736),
#  ('from', 36484),
#  ('not', 35478),
#  ('which', 30190),
#  ('disease', 29096),
#  ('also', 28927),
#  ('%', 27524),
#  ('has', 25094),
#  ('at', 24235),
#  ('other', 24070),
#  ('symptoms', 23123),
#  ("'s", 23007),
#  ('been', 22910),
#  ('syndrome', 22786),
#  ('such', 22323),
#  ('more', 21836),
#  ('was', 21145),
#  ('but', 20914),
#  ('treatment', 20401),
#  ('most', 19392),
#  ('there', 19351),
#  ('patients', 18656),
#  ('blood', 18005),
#  ('these', 17900),
#  ('–', 17690),
#  ('than', 17261),
#  ('people', 17195),
#  ('cases', 17138),
#  ('some', 16997),
#  ('cause', 16878),
#  ('if', 16429),
#  ('one', 16216),
#  ('when', 15409),
#  ('include', 15396),
#  ('they', 14987),
#  ('often', 14337),
#  ('common', 14071),
#  ('used', 13763),
#  ('disorder', 13613),
#  ('their', 13250),
#  ('risk', 13217),
#  ('due', 12987),
#  ('after', 12913),
#  ('who', 12813),
#  ('associated', 12667),
#  ('no', 12034),
#  ('cells', 11906),
#  ('usually', 11773),
#  ('pain', 11747),
#  ('i', 11664),
#  ('however', 11109),
#  ('diagnosis', 10974),
#  ('condition', 10914),
#  ('type', 10459),
#  ('found', 10309),
#  ('those', 10295),
#  ('use', 10207),
#  ('about', 10180),
#  ('all', 10044),
#  ('into', 9771),
#  ('during', 9691),
#  ('were', 9691),
#  ('cancer', 9675),
#  ('children', 9586),
#  ('first', 9567),
#  ('between', 9513),
#  ('skin', 9498),
#  ('known', 9444),
#  ('occur', 9374),
#  ('caused', 9323),
#  ('1', 9297),
#  ('infection', 9218),
#  ('will', 9105),
#  ('only', 9097),
#  ('many', 8761),
#  ('causes', 8750),
#  ('two', 8707),
#  ('should', 8659),
#  ('brain', 8541),
#  ('severe', 8512),
#  ('&', 8500),
#  ('disorders', 8463),
#  ('result', 8274),
#  ('cell', 8265),
#  ('both', 8227),
#  ('normal', 8095),
#  ('high', 8031),
#  ('body', 7860),
#  ('affected', 7810),
#  ('loss', 7783),
#  ('while', 7778),
#  ('increased', 7753),
#  ('therapy', 7699),
#  ('do', 7694),
#  ('gene', 7664),
#  ('heart', 7606),
#  ('utc', 7599),
#  ('because', 7583),
#  ('its', 7574),
#  ('including', 7537),
#  ('any', 7492),
#  ('present', 7453),
#  ('age', 7444),
#  ('years', 7402),
#  ('time', 7338),
#  ('2', 7200),
#  ('clinical', 7044),
#  ('occurs', 7013),
#  ('levels', 6952),
#  ('individuals', 6921),
#  ('surgery', 6903),
#  ('patient', 6894),
#  ('form', 6866),
#  ("'", 6731),
#  ('less', 6628),
#  ('typically', 6608),
#  ('medical', 6567),
#  ('through', 6519),
#  ('over', 6419),
#  ('women', 6419),
#  ('system', 6395),
#  ('person', 6385),
#  ('chronic', 6380),
#  ('well', 6330),
#  ('=', 6270),
#  ('being', 6265),
#  ('tissue', 6251),
#  ('where', 6185),
#  ('within', 6167),
#  ('studies', 6131),
#  ('had', 6058),
#  ('low', 5995),
#  ('bone', 5936),
#  ('although', 5908),
#  ('muscle', 5883),
#  ('study', 5882),
#  ('reported', 5838),
#  ('factors', 5788),
#  ('conditions', 5787),
#  ('commonly', 5757),
#  ('small', 5723),
#  ('early', 5719),
#  ('genetic', 5559),
#  ('3', 5541),
#  ('without', 5515),
#  ('health', 5485),
#  ('rare', 5484),
#  ('pressure', 5469),
#  ('evidence', 5448),
#  ('up', 5405),
#  ('diseases', 5350),
#  ('very', 5316),
#  ('injury', 5297),
#  ('development', 5226),
#  ('10', 5215),
#  ('acute', 5211),
#  ('results', 5197),
#  ('does', 5190),
#  ('lead', 5098),
#  ('different', 5052),
#  ('damage', 5016),
#  ('number', 5016),
#  ('mutations', 5011),
#  ('called', 4940),
#  ('seen', 4935),
#  ('rate', 4927),
#  ('problems', 4914),
#  ('several', 4904),
#  ('protein', 4876),
#  ('so', 4837),
#  ('tumor', 4783),
#  ('effects', 4764),
#  ('case', 4761),
#  ('specific', 4735),
#  ('you', 4723),
#  ('new', 4704),
#  ('even', 4702),
#  ('deficiency', 4653),
#  ('described', 4631),
#  ('following', 4594),
#  ('generally', 4587),
#  ('liver', 4578),
#  ('similar', 4577),
#  ('three', 4532),
#  ('then', 4518),
#  ('out', 4504),
#  ('function', 4485),
#  ('increase', 4483),
#  ('sometimes', 4453),
#  ('develop', 4449),
#  ('research', 4412),
#  ('death', 4409),
#  ('nerve', 4399),
#  ('physical', 4387),
#  ('using', 4385),
#  ('before', 4337),
#  ('another', 4327),
#  ('test', 4324),
#  ('primary', 4313),
#  ('likely', 4307),
#  ('changes', 4267),
#  ('types', 4255),
#  ('would', 4254),
#  ('possible', 4205),
#  ('infections', 4202),
#  ('000', 4168),
#  ('effective', 4160),
#  ('large', 4145),
#  ('5', 4135),
#  ('either', 4127),
#  ('lower', 4121),
#  ('signs', 4117),
#  ('states', 4116),
#  ('sleep', 4109),
#  ('considered', 4106),
#  ('life', 4100),
#  ('based', 4097),
#  ('term', 4079),
#  ('like', 4067),
#  ('diagnosed', 3990),
#  ('higher', 3976),
#  ('20', 3967),
#  ('lesions', 3966),
#  ('failure', 3935),
#  ('since', 3929),
#  ('among', 3919),
#  ('shown', 3904),
#  ('treated', 3882),
#  ('eye', 3874),
#  ('multiple', 3851),
#  ('part', 3846),
#  ('months', 3829),
#  ('virus', 3820),
#  ('related', 3811),
#  ('drug', 3791),
#  ('lung', 3789),
#  ('drugs', 3778),
#  ('could', 3763),
#  ('same', 3756),
#  ('characterized', 3754),
#  ('per', 3732),
#  ('around', 3717),
#  ('recommended', 3716),
#  ('kidney', 3700),
#  ('help', 3698),
#  ('them', 3687),
#  ('fever', 3671),
#  ('4', 3668),
#  ('exposure', 3665),
#  ('control', 3655),
#  ('b', 3652),
#  ('human', 3649),
#  ('pregnancy', 3645),
#  ('history', 3632),
#  ('response', 3605),
#  ('growth', 3595),
#  ('surgical', 3590),
#  ('abnormal', 3587),
#  ('inflammation', 3584),
#  ('certain', 3576),
#  ('further', 3555),
#  ('under', 3553),
#  ('—', 3548),
#  ('united', 3530),
#  ('presence', 3526),
#  ('tumors', 3524),
#  ('tests', 3523),
#  ('medications', 3515),
#  ('|', 3501),
#  ('child', 3498),
#  ('made', 3495),
#  ('areas', 3494),
#  ('e.g.', 3492),
#  ('especially', 3490),
#  ('important', 3474),
#  ('mutation', 3439),
#  ('general', 3426),
#  ('replaced-url', 3426),
#  ('example', 3416),
#  ('individual', 3343),
#  ('birth', 3339),
#  ('congenital', 3329),
#  ('onset', 3305),
#  ('significant', 3293),
#  ('year', 3290),
#  ('complications', 3283),
#  ('weeks', 3276),
#  ('side', 3267),
#  ('area', 3241),
#  ('adults', 3240),
#  ('show', 3229),
#  ('head', 3227),
#  ('2019', 3220),
#  ('left', 3214),
#  ('become', 3210),
#  ('factor', 3199),
#  ('fluid', 3190),
#  ('c', 3188),
#  ('days', 3185),
#  ('family', 3184),
#  ("n't", 3181),
#  ('causing', 3178),
#  ('long', 3175),
#  ('activity', 3173),
#  ('treatments', 3172),
#  ('replaced-dns', 3165),
#  ('6', 3154),
#  ('level', 3147),
#  ('2017', 3147),
#  ('see', 3134),
#  ('trauma', 3124),
#  ('appear', 3120),
#  ('his', 3119),
#  ('oral', 3106),
#  ('15', 3100),
#  ('bleeding', 3097),
#  ('rates', 3089),
#  ('pulmonary', 3087),
#  ('abnormalities', 3086),
#  ('experience', 3067),
#  ('what', 3060),
#  ('world', 3056),
#  ('50', 3050),
#  ('reduce', 3046),
#  ('features', 3041),
#  ('effect', 3036),
#  ('still', 3030),
#  ('each', 3026),
#  ('acid', 3021),
#  ('involved', 3021),
#  ('testing', 3018),
#  ('group', 2993),
#  ('least', 2985),
#  ('few', 2970),
#  ('though', 2963),
#  ('diagnostic', 2960),
#  ('alcohol', 2955),
#  ('30', 2950),
#  ('forms', 2941),
#  ('lack', 2913),
#  ('prevent', 2909),
#  ('much', 2902),
#  ('#', 2897),
#  ('stage', 2878),
#  ('immune', 2877),
#  ('resulting', 2873),
#  ('major', 2869),
#  ('care', 2854),
#  ('diabetes', 2851),
#  ('joint', 2847),
#  ('j', 2839),
#  ('food', 2828),
#  ('thought', 2825),
#  ('others', 2813),
#  ('population', 2790),
#  ('men', 2772),
#  ('mental', 2766),
#  ('right', 2766),
#  ('t', 2766),
#  ('decreased', 2766),
#  ('central', 2765),
#  ('et', 2764),
#  ('12', 2764),
#  ('reduced', 2762),
#  ('february', 2752),
#  ('genes', 2744),
#  ('underlying', 2741),
#  ('having', 2733),
#  ('leading', 2732),
#  ('american', 2718),
#  ('infected', 2712),
#  ('identified', 2709),
#  ('back', 2703),
#  ('various', 2698),
#  ('he', 2696),
#  ('page', 2689),
#  ('autosomal', 2688),
#  ('poor', 2675),
#  ('given', 2673),
#  ('water', 2664),
#  ('affect', 2658),
#  ('incidence', 2650),
#  ('spinal', 2642),
#  ('developing', 2642),
#  ('m', 2641),
#  ('particularly', 2638),
#  ('need', 2634),
#  ('chest', 2633),
#  ('social', 2629),
#  ('process', 2625),
#  ('weight', 2624),
#  ('involves', 2623),
#  ('thus', 2618),
#  ('muscles', 2609),
#  ('abdominal', 2600),
#  ('stress', 2593),
#  ('chromosome', 2586),
#  ('later', 2586),
#  ('secondary', 2585),
#  ('affects', 2585),
#  ('whether', 2581),
#  ('red', 2565),
#  ('severity', 2562),
#  ('mild', 2560),
#  ('against', 2548),
#  ('required', 2546),
#  ('greater', 2543),
#  ('therefore', 2539),
#  ('must', 2537),
#  ('imaging', 2519),
#  ('performed', 2518),
#  ('criteria', 2505),
#  ('association', 2500),
#  ('respiratory', 2488),
#  ('frequently', 2482),
#  ('how', 2475),
#  ('sexual', 2472),
#  ('difficult', 2472),
#  ('work', 2469),
#  ('approximately', 2441),
#  ('available', 2439),
#  ('depression', 2426),
#  ('support', 2417),
#  ('seizures', 2410),
#  ('al.', 2404),
#  ('addition', 2398),
#  ('make', 2392),
#  ('medicine', 2373),
#  ('examination', 2372),
#  ('role', 2359),
#  ('white', 2357),
#  ('upper', 2355),
#  ('motor', 2352),
#  ('cardiac', 2335),
#  ('management', 2326),
#  ('survival', 2317),
#  ('positive', 2312),
#  ('done', 2309),
#  ('cutaneous', 2300),
#  ('males', 2294),
#  ('treat', 2292),
#  ('anxiety', 2291),
#  ('developed', 2288),
#  ('medication', 2280),
#  ('25', 2280),
#  ('list', 2279),
#  ('100', 2269),
#  ('range', 2267),
#  ('urine', 2260),
#  ('hours', 2254),
#  ('information', 2245),
#  ('four', 2244),
#  ('artery', 2242),
#  ('above', 2242),
#  ('i.e.', 2241),
#  ('carcinoma', 2236),
#  ('d', 2228),
#  ('prevalence', 2220),
#  ('hearing', 2219),
#  ('countries', 2215),
#  ('second', 2212),
#  ('lesion', 2211),
#  ('until', 2201),
#  ('require', 2195),
#  ('article', 2194),
#  ('ability', 2189),
#  ('tract', 2188),
#  ('bacteria', 2188),
#  ('period', 2188),
#  ('dysfunction', 2187),
#  ('main', 2187),
#  ('inflammatory', 2185),
#  ('flow', 2184),
#  ('includes', 2184),
#  ('sign', 2182),
#  ('potential', 2181),
#  ('production', 2177),
#  ('spread', 2175),
#  ('just', 2173),
#  ('oxygen', 2171),
#  ('appears', 2166),
#  ('neck', 2163),
#  ('visual', 2161),
#  ('times', 2161),
#  ('leads', 2159),
#  ('tissues', 2146),
#  ('size', 2144),
#  ('now', 2144),
#  ('compared', 2143),
#  ('neurological', 2130),
#  ('complete', 2128),
#  ('increases', 2126),
#  ('rather', 2117),
#  ('unknown', 2112),
#  ('childhood', 2110),
#  ('movement', 2106),
#  ('estimated', 2099),
#  ('anemia', 2096),
#  ('young', 2094),
#  ('might', 2089),
#  ('day', 2089),
#  ('review', 2086),
#  ('nervous', 2082),
#  ('mouth', 2082),
#  ('humans', 2081),
#  ('observed', 2081),
#  ('state', 2073),
#  ('antibiotics', 2072),
#  ('combination', 2070),
#  ('improve', 2067),
#  ('contact', 2064),
#  ('proteins', 2063),
#  ('down', 2061),
#  ('cerebral', 2055),
#  ('way', 2054),
#  ('recent', 2053),
#  ('ct', 2052),
#  ('hair', 2049),
#  ('short', 2048),
#  ('systemic', 2043),
#  ('fracture', 2043),
#  ('elevated', 2042),
#  ('findings', 2032),
#  ('infants', 2031),
#  ('limited', 2022),
#  ('7', 2020),
#  ('breast', 2018),
#  ('vessels', 2014),
#  ('better', 2010),
#  ('decrease', 2010),
#  ('18', 2007),
#  ('initial', 2003),
#  ('single', 2001),
#  ('vitamin', 1992),
#  ('excessive', 1988),
#  ('report', 1988),
#  ('problem', 1987),
#  ('appearance', 1987),
#  ('cannot', 1986),
#  ('change', 1983),
#  ('females', 1983),
#  ('40', 1982),
#  ('useful', 1982),
#  ('speech', 1981),
#  ('injuries', 1978),
#  ('rarely', 1978),
#  ('suggested', 1973),
#  ('8', 1972),
#  ('vision', 1971),
#  ('renal', 1970),
#  ('did', 1968),
#  ('normally', 1965),
#  ('cord', 1964),
#  ('l', 1958),
#  ('formation', 1958),
#  ('ii', 1952),
#  ('mri', 1945),
#  ('million', 1942),
#  ('according', 1942),
#  ('symptom', 1933),
#  ('hormone', 1933),
#  ('national', 1932),
#  ('prognosis', 1925),
#  ('illness', 1924),
#  ('thyroid', 1908),
#  ('2018', 1906),
#  ('teeth', 1900),
#  ('defects', 1897),
#  ('january', 1894),
#  ('behavior', 1890),
#  ('radiation', 1888),
#  ('14', 1886),
#  ('produce', 1884),
#  ('complex', 1874),
#  ('e', 1873),
#  ('weakness', 1873),
#  ('needed', 1867),
#  ('cognitive', 1864),
#  ('antibodies', 1856),
#  ('necessary', 1856),
#  ('malignant', 1853),
#  ('along', 1852),
#  ('chemotherapy', 1849),
#  ('stroke', 1845),
#  ('mortality', 1845),
#  ('via', 1844),
#  ('mechanism', 1843),
#  ('once', 1842),
#  ('below', 1828),
#  ('deaths', 1826),
#  ('order', 1824),
#  ('negative', 1823),
#  ('long-term', 1818),
#  ('recessive', 1809),
#  ('good', 1809),
#  ('procedure', 1807),
#  ('eyes', 1795),
#  ('region', 1793),
#  ('last', 1792),
#  ('peripheral', 1791),
#  ('longer', 1788),
#  ('depending', 1788),
#  ('current', 1786),
#  ('swelling', 1786),
#  ('pattern', 1782),
#  ('2016', 1780),
#  ('currently', 1780),
#  ('prevention', 1778),
#  ('point', 1777),
#  ('hypertension', 1774),
#  ('facial', 1766),
#  ('serious', 1766),
#  ('name', 1765),
#  ('ear', 1763),
#  ('inherited', 1763),
#  ('classification', 1762),
#  ('us', 1761),
#  ('hand', 1760),
#  ('amount', 1757),
#  ('personality', 1756),
#  ('16', 1753),
#  ('able', 1752),
#  ('biopsy', 1752),
#  ('particular', 1749),
#  ('dna', 1748),
#  ('her', 1747),
#  ('classified', 1744),
#  ('benign', 1742),
#  ('exercise', 1742),
#  ('percent', 1740),
#  ('reaction', 1736),
#  ('difficulty', 1733),
#  ('autoimmune', 1731),
#  ('enzyme', 1719),
#  ('older', 1712),
#  ('light', 1712),
#  ('absence', 1707),
#  ('referred', 1706),
#  ('surface', 1706),
#  ('vomiting', 1696),
#  ('11', 1696),
#  ('arthritis', 1692),
#  ('itself', 1687),
#  ('followed', 1684),
#  ('language', 1682),
#  ('calcium', 1679),
#  ('bowel', 1677),
#  ('24', 1672),
#  ('we', 1672),
#  ('means', 1669),
#  ('female', 1664),
#  ('appropriate', 1659),
#  ('lymphoma', 1653),
#  ('male', 1650),
#  ('published', 1650),
#  ('adult', 1645),
#  ('method', 1644),
#  ('five', 1642),
#  ('bacterial', 1639),
#  ('ultrasound', 1638),
#  ('species', 1635),
#  ('eating', 1634),
#  ('receptor', 1634),
#  ('additional', 1634),
#  ('hospital', 1633),
#  ('little', 1631),
#  ('take', 1631),
#  ('clear', 1628),
#  ('determine', 1626),
#  ('diet', 1620),
#  ('face', 1619),
#  ('responsible', 1618),
#  ('defined', 1615),
#  ('tooth', 1613),
#  ('lungs', 1611),
#  ('h', 1609),
#  ('abuse', 1607),
#  ('progressive', 1603),
#  ('lymph', 1599),
#  ('march', 1598),
#  ('wall', 1597),
#  ('serum', 1595),
#  ('breathing', 1595),
#  ('reduction', 1594),
#  ('enough', 1593),
#  ('anterior', 1589),
#  ('viral', 1589),
#  ('vascular', 1588),
#  ('believed', 1583),
#  ('proposed', 1582),
#  ('--', 1581),
#  ('impairment', 1579),
#  ('linked', 1579),
#  ('total', 1578),
#  ('removal', 1577),
#  ('s', 1572),
#  ('dominant', 1567),
#  ('increasing', 1566),
#  ('involve', 1566),
#  ('13', 1566),
#  ('located', 1561),
#  ('direct', 1556),
#  ('fractures', 1554),
#  ('sex', 1551),
#  ('half', 1550),
#  ('21', 1547),
#  ('functional', 1546),
#  ('relatively', 1545),
#  ('22', 1541),
#  ('september', 1538),
#  ('cancers', 1536),
#  ('every', 1531),
#  ('site', 1524),
#  ('screening', 1524),
#  ('third', 1523),
#  ('typical', 1523),
#  ('provide', 1521),
#  ('too', 1520),
#  ('defect', 1518),
#  ('discussion', 1517),
#  ('17', 1511),
#  ('characteristic', 1510),
#  ('overall', 1510),
#  ('taken', 1505),
#  ('involvement', 1501),
#  ('p.', 1500),
#  ('frequent', 1497),
#  ('removed', 1497),
#  ('19', 1496),
#  ('active', 1494),
#  ('obstruction', 1493),
#  ('posterior', 1493),
#  ('membrane', 1493),
#  ('suggest', 1493),
#  ('almost', 1489),
#  ('phase', 1486),
#  ('memory', 1485),
#  ('healthy', 1485),
#  ('specifically', 1483),
#  ('quality', 1479),
#  ('simple', 1477),
#  ('impaired', 1477),
#  ('data', 1473),
#  ('template', 1470),
#  ('parts', 1467),
#  ('r', 1465),
#  ('get', 1463),
#  ('involving', 1462),
#  ('headache', 1461),
#  ('groups', 1461),
#  ('developmental', 1460),
#  ('old', 1460),
#  ('gastrointestinal', 1459),
#  ('organs', 1458),
#  ('volume', 1457),
#  ('suspected', 1457),
#  ('iron', 1455),
#  ('urinary', 1453),
#  ('benefit', 1451),
#  ('journal', 1450),
#  ('rapid', 1449),
#  ('standard', 1449),
#  ('bladder', 1448),
#  ('90', 1448),
#  ('my', 1447),
#  ('cysts', 1444),
#  ('methods', 1441),
#  ('pneumonia', 1440),
#  ('significantly', 1440),
#  ('psychological', 1437),
#  ('degree', 1437),
#  ('metabolic', 1435),
#  ('60', 1434),
#  ('researchers', 1434),
#  ('9', 1433),
#  ('source', 1433),
#  ('course', 1430),
#  ('making', 1430),
#  ('local', 1429),
#  ('episodes', 1427),
#  ('bones', 1426),
#  ('agents', 1419),
#  ('upon', 1418),
#  ('occurring', 1414),
#  ('mass', 1410),
#  ('requires', 1409),
#  ('ventricular', 1408),
#  ('remains', 1407),
#  ('dental', 1406),
#  ('six', 1404),
#  ('yet', 1404),
#  ('recurrent', 1400),
#  ('majority', 1400),
#  ('glucose', 1399),
#  ('best', 1398),
#  ('g', 1393),
#  ('always', 1391),
#  ('position', 1390),
#  ('aortic', 1389),
#  ('suggests', 1384),
#  ('showed', 1382),
#  ('outcomes', 1380),
#  ('prior', 1378),
#  ('your', 1372),
#  ('own', 1367),
#  ('prolonged', 1366),
#  ('late', 1366),
#  ('plasma', 1364),
#  ('despite', 1364),
#  ('shows', 1363),
#  ('vary', 1362),
#  ('confirmed', 1360),
#  ('tend', 1358),
#  ('average', 1356),
#  ('primarily', 1355),
#  ('frequency', 1354),
#  ('location', 1354),
#  ('parents', 1351),
#  ('fetal', 1350),
#  ('leukemia', 1349),
#  ('highly', 1349),
#  ('air', 1348),
#  ('mg', 1346),
#  ('infectious', 1345),
#  ('80', 1344),
#  ('progression', 1338),
#  ('image', 1338),
#  ('23', 1335),
#  ('cervical', 1333),
#  ('treating', 1332),
#  ('named', 1331),
#  ('wikipedia', 1330),
#  ('stomach', 1328),
#  ('hepatitis', 1327),
#  ('instead', 1327),
#  ('smoking', 1322),
#  ('sensitivity', 1318),
#  ('marrow', 1318),
#  ('psychiatric', 1318),
#  ('ed', 1316),
#  ('movements', 1312),
#  ('internal', 1312),
#  ('diarrhea', 1311),
#  ('s.', 1309),
#  ('approach', 1308),
#  ('“', 1307),
#  ('attacks', 1306),
#  ('”', 1306),
#  ('recovery', 1303),
#  ('analysis', 1301),
#  ('techniques', 1299),
#  ('cyst', 1296),
#  ('disability', 1296),
#  ('becomes', 1296),
#  ('foot', 1292),
#  ('directly', 1290),
#  ('end', 1289),
#  ('edema', 1287),
#  ('external', 1285),
#  ('expression', 1285),
#  ('epilepsy', 1280),
#  ('open', 1280),
#  ('place', 1273),
#  ('resistance', 1272),
#  ('2013', 1270),
#  ('release', 1269),
#  ('unclear', 1265),
#  ('occasionally', 1260),
#  ('gland', 1258),
#  ('mother', 1258),
#  ('avoid', 1258),
#  ('sensory', 1256),
#  ('block', 1254),
#  ('baby', 1254),
#  ('fear', 1251),
#  ('2015', 1251),
#  ('fatigue', 1249),
#  ('international', 1245),
#  ('alone', 1244),
#  ('subsequent', 1244),
#  ('here', 1244),
#  ('university', 1242),
#  ('animals', 1242),
#  ('occurred', 1242),
#  ('vaccine', 1241),
#  ('acquired', 1239),
#  ('presentation', 1239),
#  ('insulin', 1239),
#  ('space', 1236),
#  ('asymptomatic', 1235),
#  ('painful', 1235),
#  ('variety', 1234),
#  ('knee', 1229),
#  ('produced', 1229),
#  ('affecting', 1227),
#  ('stages', 1219),
#  ('transmission', 1216),
#  ('persons', 1214),
#  ('syndromes', 1213),
#  ('moderate', 1210),
#  ('shock', 1208),
#  ('nasal', 1207),
#  ('public', 1205),
#  ('terms', 1204),
#  ('excess', 1202),
#  ('meaning', 1200),
#  ('intervention', 1198),
#  ('mechanisms', 1197),
#  ('atrophy', 1195),
#  ('refers', 1195),
#  ('presents', 1195),
#  ('reports', 1194),
#  ('distal', 1192),
#  ('regions', 1192),
#  ('trials', 1190),
#  ('together', 1187),
#  ('arm', 1187),
#  ('close', 1186),
#  ('partial', 1184),
#  ('environmental', 1184),
#  ('u.s.', 1182),
#  ('ovarian', 1181),
#  ('characteristics', 1177),
#  ('advanced', 1176),
#  ('scan', 1176),
#  ('activities', 1175),
#  ('indicated', 1175),
#  ('sudden', 1174),
#  ('cold', 1169),
#  ('k', 1169),
#  ('fat', 1168),
#  ('emotional', 1165),
#  ('full', 1165),
#  ('previously', 1164),
#  ('fact', 1163),
#  ('hereditary', 1161),
#  ('obesity', 1160),
#  ('link', 1160),
#  ('middle', 1158),
#  ('action', 1158),
#  ('lateral', 1157),
#  ('repair', 1156),
#  ('dementia', 1156),
#  ('identify', 1155),
#  ('mainly', 1155),
#  ('70', 1154),
#  ('structures', 1153),
#  ('section', 1153),
#  ('hiv', 1152),
#  ('nature', 1152),
#  ('poisoning', 1151),
#  ('iii', 1148),
#  ('nausea', 1148),
#  ('free', 1147),
#  ('possibly', 1146),
#  ('born', 1146),
#  ('paralysis', 1145),
#  ('limb', 1145),
#  ('reason', 1144),
#  ('organ', 1143),
#  ('daily', 1142),
#  ('contrast', 1142),
#  ('find', 1141),
#  ('soft', 1140),
#  ('nodes', 1140),
#  ('behavioral', 1139),
#  ('2010', 1139),
#  ('intestinal', 1138),
#  ('reducing', 1138),
#  ('2005', 1137),
#  ('attention', 1136),
#  ('stenosis', 1136),
#  ('completely', 1136),
#  ('issues', 1136),
#  ('laboratory', 1136),
#  ('detected', 1135),
#  ('venous', 1133),
#  ('intravenous', 1132),
#  ('measures', 1132),
#  ...]

# %%
print(len(counter_lemmas))
counter_lemmas.most_common()
# Out:
# 151476
# [('the', 471282),
#  ('be', 374139),
#  ('of', 339325),
#  ('and', 246131),
#  ('in', 213056),
#  ('to', 194037),
#  ('a', 177881),
#  ('with', 96718),
#  ('or', 87221),
#  ('as', 77064),
#  ('have', 72802),
#  ('that', 66384),
#  ('for', 66162),
#  ('it', 54784),
#  ('by', 54352),
#  ('may', 51461),
#  ('can', 45101),
#  ('an', 40661),
#  ('this', 39477),
#  ('not', 38659),
#  ('cause', 38126),
#  ('on', 37738),
#  ('from', 36484),
#  ('disease', 34446),
#  ('they', 31924),
#  ('which', 30190),
#  ('also', 28927),
#  ('%', 27524),
#  ('other', 26883),
#  ('patient', 25550),
#  ('symptom', 25056),
#  ('at', 24235),
#  ('syndrome', 23999),
#  ('treatment', 23573),
#  ('such', 22323),
#  ('disorder', 22076),
#  ('case', 21898),
#  ('more', 21840),
#  ('but', 20914),
#  ("'s", 20439),
#  ('cell', 20171),
#  ('most', 19392),
#  ('there', 19351),
#  ('blood', 18011),
#  ('these', 17900),
#  ('include', 17891),
#  ('–', 17690),
#  ('occur', 17636),
#  ('do', 17566),
#  ('than', 17261),
#  ('people', 17258),
#  ('some', 16997),
#  ('condition', 16704),
#  ('one', 16665),
#  ('if', 16430),
#  ('when', 15409),
#  ('use', 15317),
#  ('type', 14725),
#  ('often', 14337),
#  ('result', 14193),
#  ('i', 14142),
#  ('risk', 14076),
#  ('common', 14071),
#  ('use|used', 13456),
#  ('infection', 13420),
#  ('child', 13084),
#  ('due', 12987),
#  ('after', 12913),
#  ('who', 12813),
#  ('high', 12705),
#  ('study', 12153),
#  ('no', 12076),
#  ('pain', 12069),
#  ('usually', 11773),
#  ('find', 11544),
#  ('associate|associated', 11290),
#  ('cancer', 11211),
#  ('however', 11109),
#  ('@card@', 11017),
#  ('diagnosis', 11000),
#  ('form', 10890),
#  ('year', 10692),
#  ('gene', 10408),
#  ('those', 10295),
#  ('individual', 10264),
#  ('about', 10180),
#  ('low', 10132),
#  ('level', 10100),
#  ('all', 10044),
#  ('show', 9884),
#  ('into', 9771),
#  ('during', 9691),
#  ('first', 9567),
#  ('skin', 9525),
#  ('between', 9513),
#  ('will', 9502),
#  ('time', 9486),
#  ('present', 9391),
#  ('know|known', 9384),
#  ('1', 9297),
#  ('only', 9097),
#  ('factor', 8987),
#  ('many', 8761),
#  ('brain', 8710),
#  ('two', 8707),
#  ('body', 8664),
#  ('should', 8660),
#  ('therapy', 8576),
#  ('severe', 8522),
#  ('&', 8500),
#  ('muscle', 8492),
#  ('mutation', 8450),
#  ('age', 8399),
#  ('tissue', 8397),
#  ('tumor', 8307),
#  ('see', 8302),
#  ('@ord@', 8289),
#  ('both', 8227),
#  ('lead', 8122),
#  ('normal', 8097),
#  ('rate', 8019),
#  ('loss', 7957),
#  ('test', 7941),
#  ('effect', 7826),
#  ('while', 7780),
#  ('heart', 7651),
#  ('person', 7599),
#  ('utc', 7599),
#  ('because', 7583),
#  ('drug', 7570),
#  ('system', 7521),
#  ('any', 7492),
#  ('woman', 7419),
#  ('bone', 7362),
#  ('report', 7292),
#  ('injury', 7275),
#  ('including', 7239),
#  ('surgery', 7209),
#  ('2', 7200),
#  ('clinical', 7044),
#  ('protein', 6939),
#  ('well', 6917),
#  ('problem', 6901),
#  ('make', 6833),
#  ('early', 6807),
#  ('area', 6735),
#  ("'", 6731),
#  ('less', 6628),
#  ('increase', 6609),
#  ('typically', 6608),
#  ('medical', 6568),
#  ('increased|increase', 6542),
#  ('through', 6519),
#  ('small', 6500),
#  ('over', 6419),
#  ('chronic', 6380),
#  ('sign', 6299),
#  ('=', 6270),
#  ('change', 6254),
#  ('death', 6235),
#  ('term', 6232),
#  ('he', 6185),
#  ('where', 6185),
#  ('lesion', 6179),
#  ('within', 6167),
#  ('you', 6107),
#  ('appear', 5909),
#  ('although', 5908),
#  ('pressure', 5798),
#  ('medication', 5795),
#  ('involve', 5770),
#  ('commonly', 5757),
#  ('human', 5730),
#  ('number', 5694),
#  ('rare', 5687),
#  ('eye', 5669),
#  ('evidence', 5563),
#  ('genetic', 5559),
#  ('3', 5541),
#  ('nerve', 5528),
#  ('without', 5515),
#  ('large', 5494),
#  ('health', 5485),
#  ('diagnose', 5471),
#  ('up', 5430),
#  ('lung', 5400),
#  ('develop', 5364),
#  ('very', 5316),
#  ('part', 5314),
#  ('function', 5285),
#  ('day', 5274),
#  ('development', 5269),
#  ('affect', 5250),
#  ('damage', 5215),
#  ('10', 5215),
#  ('acute', 5211),
#  ('deficiency', 5159),
#  ('become', 5111),
#  ('different', 5052),
#  ('new', 4962),
#  ('several', 4904),
#  ('adult', 4885),
#  ('call|called', 4883),
#  ('so', 4837),
#  ('base', 4792),
#  ('specific', 4761),
#  ('even', 4703),
#  ('describe|described', 4623),
#  ('liver', 4605),
#  ('group', 4594),
#  ('generally', 4587),
#  ('virus', 4585),
#  ('similar', 4577),
#  ('research', 4571),
#  ('kidney', 4566),
#  ('prevent', 4544),
#  ('would', 4535),
#  ('three', 4532),
#  ('then', 4518),
#  ('out', 4507),
#  ('affect|affected', 4502),
#  ('sometimes', 4453),
#  ('month', 4433),
#  ('physical', 4387),
#  ('help', 4374),
#  ('response', 4367),
#  ('activity', 4348),
#  ('week', 4344),
#  ('before', 4337),
#  ('another', 4327),
#  ('experience', 4324),
#  ('primary', 4316),
#  ('likely', 4312),
#  ('possible', 4205),
#  ('good', 4201),
#  ('pregnancy', 4181),
#  ('example', 4174),
#  ('000', 4168),
#  ('effective', 4160),
#  ('stage', 4147),
#  ('sleep', 4140),
#  ('5', 4135),
#  ('either', 4127),
#  ('complication', 4125),
#  ('life', 4100),
#  ('consider|considered', 4098),
#  ('like', 4085),
#  ('require', 4078),
#  ('family', 4068),
#  ('control', 4048),
#  ('birth', 4033),
#  ('failure', 4015),
#  ('20', 3967),
#  ('feature', 3965),
#  ('male', 3944),
#  ('joint', 3934),
#  ('since', 3929),
#  ('characterize', 3925),
#  ('among', 3919),
#  ('fluid', 3913),
#  ('exposure', 3878),
#  ('long', 3877),
#  ('multiple', 3861),
#  ('fever', 3818),
#  ('food', 3809),
#  ('reduce', 3797),
#  ('treat|treated', 3788),
#  ('acid', 3784),
#  ('abnormality', 3780),
#  ('could', 3763),
#  ('same', 3756),
#  ('growth', 3743),
#  ('per', 3732),
#  ('around', 3717),
#  ('history', 3711),
#  ('treat', 3683),
#  ('side', 3681),
#  ('4', 3668),
#  ('b', 3653),
#  ('female', 3647),
#  ('population', 3646),
#  ('great', 3643),
#  ('need', 3619),
#  ('inflammation', 3606),
#  ('fracture', 3604),
#  ('surgical', 3590),
#  ('abnormal', 3587),
#  ('certain', 3576),
#  ('under', 3553),
#  ('—', 3548),
#  ('presence', 3528),
#  ('tooth', 3513),
#  ('|', 3501),
#  ('e.g.', 3492),
#  ('especially', 3490),
#  ('important', 3474),
#  ('page', 3464),
#  ('think', 3453),
#  ('suggest', 3441),
#  ('general', 3427),
#  ('replaced-url', 3426),
#  ('defect', 3420),
#  ('movement', 3418),
#  ('process', 3406),
#  ('man', 3400),
#  ('far', 3375),
#  ('state', 3346),
#  ('head', 3343),
#  ('congenital', 3329),
#  ('seizure', 3325),
#  ('recommend|recommended', 3313),
#  ('affected|affect', 3306),
#  ('onset', 3305),
#  ('significant', 3293),
#  ('united', 3274),
#  ('old', 3258),
#  ('provide', 3248),
#  ('indicate', 3246),
#  ('decrease', 3234),
#  ('article', 3227),
#  ('perform', 3226),
#  ('2019', 3220),
#  ('c', 3188),
#  ('artery', 3178),
#  ('trauma', 3178),
#  ('replaced-dns', 3165),
#  ('6', 3154),
#  ('2017', 3147),
#  ('lack', 3139),
#  ('period', 3111),
#  ('oral', 3106),
#  ('15', 3100),
#  ('chromosome', 3094),
#  ('pulmonary', 3087),
#  ('method', 3085),
#  ('world', 3063),
#  ('infant', 3062),
#  ('what', 3061),
#  ('american', 3060),
#  ('50', 3050),
#  ('mechanism', 3040),
#  ('remove', 3035),
#  ('still', 3033),
#  ('each', 3026),
#  ('region', 2985),
#  ('least', 2985),
#  ('alcohol', 2972),
#  ('few', 2970),
#  ('work', 2963),
#  ('though', 2963),
#  ('right', 2960),
#  ('diagnostic', 2960),
#  ('30', 2950),
#  ('states', 2948),
#  ('mild', 2942),
#  ('antibiotic', 2915),
#  ('poor', 2903),
#  ('much', 2902),
#  ('follow', 2898),
#  ('#', 2897),
#  ('care', 2893),
#  ('immune', 2877),
#  ('major', 2869),
#  ('procedure', 2869),
#  ('following|follow', 2867),
#  ('young', 2863),
#  ('diabetes', 2851),
#  ('j', 2839),
#  ('hand', 2821),
#  ('difficulty', 2818),
#  ('support', 2788),
#  ('way', 2782),
#  ('mental', 2766),
#  ('t', 2766),
#  ('central', 2765),
#  ('et', 2764),
#  ('12', 2764),
#  ('association', 2762),
#  ('produce', 2757),
#  ('february', 2752),
#  ('cyst', 2740),
#  ('back', 2740),
#  ('vessel', 2730),
#  ('incidence', 2730),
#  ('reaction', 2725),
#  ('antibody', 2720),
#  ('criterion', 2712),
#  ('water', 2710),
#  ('she', 2708),
#  ('various', 2698),
#  ('stress', 2695),
#  ('behavior', 2692),
#  ('autosomal', 2688),
#  ('characteristic', 2687),
#  ('range', 2686),
#  ('allow', 2681),
#  ('weight', 2675),
#  ('medicine', 2671),
#  ('country', 2665),
#  ('pattern', 2662),
#  ('m', 2646),
#  ('amount', 2646),
#  ('chest', 2643),
#  ('spinal', 2642),
#  ('take', 2640),
#  ('particularly', 2638),
#  ('carcinoma', 2636),
#  ('relate|related', 2632),
#  ('hormone', 2631),
#  ('social', 2629),
#  ('underlying|underlie', 2624),
#  ('receptor', 2623),
#  ('hour', 2618),
#  ('thus', 2618),
#  ('examination', 2614),
#  ('testing|test', 2613),
#  ('abdominal', 2603),
#  ('organ', 2601),
#  ('secondary', 2587),
#  ('bacterium', 2583),
#  ('whether', 2581),
#  ('red', 2580),
#  ('severity', 2577),
#  ('contain', 2561),
#  ('source', 2558),
#  ('against', 2548),
#  ('bleeding|bleed', 2547),
#  ('therefore', 2539),
#  ('must', 2538),
#  ('second', 2531),
#  ('begin', 2530),
#  ('role', 2524),
#  ('list', 2522),
#  ('review', 2515),
#  ('improve', 2495),
#  ('ability', 2493),
#  ('respiratory', 2488),
#  ('compare', 2485),
#  ('attack', 2483),
#  ('frequently', 2482),
#  ('get', 2477),
#  ('how', 2475),
#  ('sexual', 2472),
#  ('difficult', 2472),
#  ('result|resulting', 2468),
#  ('white', 2466),
#  ('involve|involved', 2448),
#  ('depression', 2447),
#  ('exercise', 2443),
#  ('approximately', 2441),
#  ('available', 2439),
#  ('short', 2425),
#  ('addition', 2423),
#  ('spread', 2420),
#  ('enzyme', 2418),
#  ('episode', 2404),
#  ('al.', 2404),
#  ('require|required', 2401),
#  ('site', 2389),
#  ('positive', 2382),
#  ('identify|identified', 2376),
#  ('upper', 2361),
#  ('motor', 2354),
#  ('tract', 2348),
#  ('agent', 2344),
#  ('give|given', 2342),
#  ('illness', 2341),
#  ('we', 2339),
#  ('cardiac', 2335),
#  ('place', 2334),
#  ('survival', 2332),
#  ('point', 2328),
#  ('management', 2328),
#  ('potential', 2325),
#  ('foot', 2323),
#  ('animal', 2319),
#  ('dysfunction', 2312),
#  ('anxiety', 2306),
#  ('cutaneous', 2300),
#  ('lead|leading', 2282),
#  ('25', 2280),
#  ('name', 2280),
#  ('combination', 2275),
#  ('breast', 2272),
#  ('100', 2269),
#  ('flow', 2265),
#  ('ear', 2263),
#  ('urine', 2260),
#  ('size', 2258),
#  ('believe', 2248),
#  ('information', 2247),
#  ('four', 2244),
#  ('above', 2242),
#  ('prevalence', 2241),
#  ('i.e.', 2241),
#  ('vitamin', 2238),
#  ('complete', 2238),
#  ('outcome', 2237),
#  ('vary', 2233),
#  ('d', 2228),
#  ('last', 2224),
#  ('hair', 2207),
#  ('until', 2201),
#  ('stroke', 2198),
#  ('production', 2197),
#  ('decreased|decrease', 2189),
#  ('contact', 2188),
#  ('main', 2187),
#  ('inflammatory', 2185),
#  ('neck', 2180),
#  ('late', 2180),
#  ('just', 2173),
#  ('oxygen', 2172),
#  ('gland', 2170),
#  ('technique', 2169),
#  ('visual', 2165),
#  ('detect', 2155),
#  ('now', 2144),
#  ('left|leave', 2143),
#  ('neurological', 2130),
#  ('leg', 2121),
#  ('rather', 2117),
#  ('mouth', 2115),
#  ('unknown', 2114),
#  ('childhood', 2112),
#  ('cord', 2106),
#  ('surface', 2105),
#  ('ct', 2103),
#  ('parent', 2098),
#  ('anemia', 2096),
#  ('image|imaging', 2091),
#  ('complex', 2090),
#  ('membrane', 2090),
#  ('biopsy', 2090),
#  ('might', 2089),
#  ('benefit', 2086),
#  ('nervous', 2082),
#  ('image', 2079),
#  ('tend', 2078),
#  ('issue', 2073),
#  ('down', 2069),
#  ('appearance', 2056),
#  ('cerebral', 2055),
#  ('recent', 2053),
#  ('trial', 2048),
#  ('systemic', 2043),
#  ('lymphoma', 2039),
#  ('finding', 2032),
#  ('7', 2020),
#  ('impairment', 2019),
#  ('initial', 2018),
#  ('refer', 2010),
#  ('single', 2009),
#  ('baby', 2008),
#  ('wall', 2008),
#  ('18', 2007),
#  ('intervention', 2005),
#  ('mean', 1997),
#  ('structure', 1993),
#  ('die', 1992),
#  ('vision', 1990),
#  ('excessive', 1988),
#  ('formation', 1987),
#  ('cannot', 1986),
#  ('speech', 1985),
#  ('40', 1982),
#  ('useful', 1982),
#  ('node', 1979),
#  ('rarely', 1978),
#  ('8', 1972),
#  ('l', 1971),
#  ('renal', 1970),
#  ('degree', 1967),
#  ('normally', 1965),
#  ('depend', 1960),
#  ('dose', 1956),
#  ('accord', 1953),
#  ('ii', 1952),
#  ('mri', 1945),
#  ('million', 1942),
#  ('arm', 1935),
#  ('hospital', 1934),
#  ('national', 1934),
#  ('classification', 1933),
#  ('prognosis', 1925),
#  ('thyroid', 1908),
#  ('light', 1902),
#  ('weakness', 1901),
#  ('later', 1900),
#  ('suggest|suggested', 1896),
#  ('radiation', 1895),
#  ('january', 1894),
#  ('seem', 1891),
#  ('reason', 1891),
#  ('physician', 1887),
#  ('14', 1886),
#  ('event', 1885),
#  ('measure', 1885),
#  ('avoid', 1879),
#  ('approach', 1878),
#  ('e', 1873),
#  ('limb', 1869),
#  ('cognitive', 1864),
#  ('need|needed', 1864),
#  ('template', 1862),
#  ('order', 1859),
#  ('negative', 1857),
#  ('necessary', 1856),
#  ('malignant', 1853),
#  ('mortality', 1852),
#  ('along', 1852),
#  ('disability', 1851),
#  ('chemotherapy', 1849),
#  ('via', 1844),
#  ('diet', 1843),
#  ('once', 1842),
#  ('scan', 1842),
#  ('current', 1841),
#  ('clear', 1835),
#  ('hearing|hear', 1832),
#  ('below', 1828),
#  ('face', 1825),
#  ('long-term', 1818),
#  ('recessive', 1809),
#  ('personality', 1807),
#  ('peripheral', 1792),
#  ('progress', 1791),
#  ('mother', 1790),
#  ('2016', 1780),
#  ('currently', 1780),
#  ('ed', 1780),
#  ('prevention', 1780),
#  ('center', 1778),
#  ('trigger', 1776),
#  ('come', 1776),
#  ('hypertension', 1774),
#  ('language', 1773),
#  ('facial', 1768),
#  ('serious', 1766),
#  ('option', 1761),
#  ('observe|observed', 1761),
#  ('16', 1753),
#  ('able', 1752),
#  ('difference', 1750),
#  ('start', 1750),
#  ('dna', 1749),
#  ('particular', 1749),
#  ('memory', 1748),
#  ('go', 1746),
#  ('benign', 1742),
#  ('developing|develop', 1741),
#  ('percent', 1740),
#  ('vaccine', 1739),
#  ('determine', 1739),
#  ('word', 1733),
#  ('autoimmune', 1731),
#  ('absence', 1729),
#  ('link', 1723),
#  ('location', 1722),
#  ('classify|classified', 1712),
#  ('pathway', 1711),
#  ('bowel', 1710),
#  ('sex', 1705),
#  ('exist', 1705),
#  ('mass', 1700),
#  ('variant', 1697),
#  ('11', 1696),
#  ('reduced|reduce', 1696),
#  ('arthritis', 1692),
#  ('reduction', 1692),
#  ('phase', 1689),
#  ('itself', 1687),
#  ('standard', 1687),
#  ('calcium', 1679),
#  ('develop|developed', 1676),
#  ('play', 1676),
#  ('24', 1672),
#  ('locate', 1664),
#  ('appropriate', 1661),
#  ('arise', 1659),
#  ('discussion', 1657),
#  ('substance', 1654),
#  ('ulcer', 1644),
#  ('five', 1642),
#  ('abuse', 1641),
#  ('bacterial', 1639),
#  ('ultrasound', 1638),
#  ('species', 1635),
#  ('additional', 1634),
#  ('little', 1631),
#  ('concentration', 1629),
#  ('end', 1627),
#  ('position', 1623),
#  ('vein', 1618),
#  ('responsible', 1618),
#  ('category', 1615),
#  ('carry', 1611),
#  ('h', 1610),
#  ('account', 1607),
#  ('progressive', 1604),
#  ('march', 1600),
#  ('lymph', 1599),
#  ('serum', 1596),
#  ('enough', 1593),
#  ('inhibitor', 1591),
#  ('anterior', 1589),
#  ('viral', 1589),
#  ('block', 1588),
#  ('vascular', 1588),
#  ('space', 1585),
#  ('removal', 1584),
#  ('total', 1583),
#  ('--', 1581),
#  ('infected|infect', 1575),
#  ('s', 1572),
#  ('us', 1572),
#  ('direct', 1570),
#  ('dominant', 1568),
#  ('release', 1567),
#  ('volume', 1566),
#  ('13', 1566),
#  ('refer|referred', 1564),
#  ('describe', 1562),
#  ('obstruction', 1560),
#  ('action', 1560),
#  ('identify', 1557),
#  ('simple', 1551),
#  ('half', 1550),
#  ('course', 1550),
#  ('21', 1547),
#  ('functional', 1546),
#  ('relatively', 1545),
#  ('22', 1541),
#  ('september', 1538),
#  ('give', 1538),
#  ('consist', 1536),
#  ('headache', 1532),
#  ('researcher', 1531),
#  ('every', 1531),
#  ('frequency', 1529),
#  ('quality', 1524),
#  ('third', 1523),
#  ('typical', 1523),
#  ('link|linked', 1522),
#  ('too', 1520),
#  ('x-ray', 1520),
#  ('line', 1519),
#  ('healthy', 1517),
#  ('journal', 1513),
#  ('17', 1511),
#  ('overall', 1510),
#  ('involvement', 1507),
#  ('presentation', 1505),
#  ('p.', 1500),
#  ('frequent', 1499),
#  ('19', 1496),
#  ('active', 1494),
#  ('posterior', 1493),
#  ('knee', 1492),
#  ('almost', 1489),
#  ('specifically', 1483),
#  ('take|taken', 1479),
#  ('product', 1478),
#  ('data', 1474),
#  ('slow', 1470),
#  ('pneumonia', 1469),
#  ('r', 1465),
#  ('bladder', 1460),
#  ('developmental', 1460),
#  ('iron', 1459),
#  ('gastrointestinal', 1459),
#  ('force', 1457),
#  ('define|defined', 1456),
#  ('create', 1455),
#  ('urinary', 1453),
#  ('rapid', 1450),
#  ('screening|screen', 1450),
#  ('90', 1448),
#  ('look', 1440),
#  ('significantly', 1440),
#  ('relationship', 1439),
#  ('contribute', 1439),
#  ('local', 1439),
#  ('psychological', 1437),
#  ('feel', 1436),
#  ('metabolic', 1435),
#  ('60', 1434),
#  ('swelling|swell', 1434),
#  ('9', 1433),
#  ('publish|published', 1432),
#  ('open', 1428),
#  ('fear', 1426),
#  ('minute', 1426),
#  ('neuron', 1425),
#  ('upon', 1418),
#  ('follow|following', 1413),
#  ('ventricular', 1408),
#  ('doctor', 1408),
#  ('dental', 1406),
#  ('occur|occurring', 1405),
#  ('six', 1404),
#  ('yet', 1404),
#  ('sound', 1401),
#  ('depend|depending', 1401),
#  ('recurrent', 1400),
#  ('majority', 1400),
#  ('glucose', 1399),
#  ('make|making', 1399),
#  ('host', 1398),
#  ('edit', 1396),
#  ('expression', 1395),
#  ('situation', 1395),
#  ('g', 1393),
#  ('always', 1391),
#  ('aortic', 1389),
#  ('outbreak', 1383),
#  ('average', 1382),
#  ('inherit', 1382),
#  ('close', 1382),
#  ('practice', 1378),
#  ('prior', 1378),
#  ('own', 1377),
#  ('component', 1377),
#  ('section', 1376),
#  ('air', 1370),
#  ('suffer', 1370),
#  ('elevated|elevate', 1365),
#  ('plasma', 1364),
#  ('theory', 1364),
#  ('despite', 1364),
#  ('act', 1364),
#  ('malformation', 1355),
#  ('primarily', 1355),
#  ('count', 1354),
#  ('sensitivity', 1353),
#  ('stomach', 1351),
#  ('fetal', 1350),
#  ('leukemia', 1349),
#  ('highly', 1349),
#  ('model', 1349),
#  ('finger', 1348),
#  ('prolonged|prolong', 1347),
#  ('mg', 1346),
#  ('infectious', 1345),
#  ('80', 1344),
#  ('progression', 1342),
#  ('subtype', 1340),
#  ('fat', 1339),
#  ('23', 1335),
#  ('cervical', 1333),
#  ('airway', 1332),
#  ('valve', 1331),
#  ('wikipedia', 1330),
#  ('sensation', 1329),
#  ('bad', 1328),
#  ('hepatitis', 1327),
#  ('instead', 1327),
#  ('fact', 1323),
#  ('marrow', 1319),
#  ('psychiatric', 1318),
#  ('remain|remains', 1317),
#  ('steroid', 1314),
#  ('internal', 1313),
#  ('recovery', 1313),
#  ('diarrhea', 1311),
#  ('maintain', 1311),
#  ('sample', 1311),
#  ('variety', 1310),
#  ('s.', 1309),
#  ('name|named', 1308),
#  ('“', 1307),
#  ('”', 1306),
#  ('deficit', 1304),
#  ('tumour', 1301),
#  ('analysis', 1301),
#  ('organization', 1297),
#  ('directly', 1290),
#  ('manifestation', 1289),
#  ('culture', 1288),
#  ('edema', 1287),
#  ('external', 1286),
#  ('target', 1283),
#  ('epilepsy', 1280),
#  ('object', 1278),
#  ('undergo', 1278),
#  ('associated|associate', 1276),
#  ('resistance', 1274),
#  ('2013', 1270),
#  ('deletion', 1269),
#  ('university', 1268),
#  ('unclear', 1265),
#  ('guideline', 1265),
#  ('subject', 1263),
#  ('cavity', 1261),
#  ('occasionally', 1260),
#  ('laboratory', 1260),
#  ('user', 1260),
#  ('fatigue', 1259),
#  ('sensory', 1256),
#  ('deep', 1255),
#  ('supply', 1255),
#  ('2015', 1251),
#  ('respond', 1250),
#  ('task', 1247),
#  ('environment', 1247),
#  ('strain', 1245),
#  ('insulin', 1245),
#  ('international', 1245),
#  ('alone', 1244),
#  ('remain', 1244),
#  ('subsequent', 1244),
#  ('here', 1244),
#  ('chance', 1243),
#  ('repair', 1243),
#  ('tube', 1242),
#  ('corticosteroid', 1242),
#  ('view', 1242),
#  ('shock', 1239),
#  ('cure', 1237),
#  ('school', 1237),
#  ('asymptomatic', 1235),
#  ('chemical', 1235),
#  ('painful', 1235),
#  ('atrophy', 1234),
#  ('transmission', 1230),
#  ('allergy', 1227),
#  ('live', 1225),
#  ('moderate', 1225),
#  ('color', 1224),
#  ('cold', 1224),
#  ('grade', 1224),
#  ('strong', 1221),
#  ('estimate|estimated', 1220),
#  ('affect|affecting', 1220),
#  ('rash', 1216),
#  ('copy', 1212),
#  ('increase|increased', 1211),
#  ('dog', 1210),
#  ('say', 1209),
#  ('limited|limit', 1209),
#  ('focus', 1208),
#  ('nasal', 1207),
#  ('excess', 1207),
#  ('conduct', 1207),
#  ('pathology', 1206),
#  ('public', 1205),
#  ('improvement', 1202),
#  ('exhibit', 1200),
#  ('definition', 1199),
#  ('injection', 1198),
#  ('distal', 1192),
#  ('mean|meaning', 1188),
#  ('together', 1187),
#  ('partial', 1184),
#  ('environmental', 1184),
#  ('u.s.', 1182),
#  ('ovarian', 1181),
#  ('program', 1181),
#  ('intake', 1178),
#  ('assessment', 1177),
#  ('soft', 1175),
#  ('sudden', 1174),
#  ('full', 1174),
#  ('access', 1171),
#  ('century', 1171),
#  ('confirm|confirmed', 1170),
#  ('k', 1169),
#  ('contrast', 1169),
#  ('free', 1165),
#  ('emotional', 1165),
#  ('rupture', 1164),
#  ('continue', 1164),
#  ('previously', 1164),
#  ('lateral', 1162),
#  ('bite', 1161),
#  ('hereditary', 1161),
#  ('obesity', 1160),
#  ('middle', 1159),
#  ('class', 1159),
#  ('cycle', 1159),
#  ('ventricle', 1156),
#  ('dementia', 1156),
#  ('mainly', 1155),
#  ('70', 1154),
#  ('hiv', 1152),
#  ('nature', 1152),
#  ('paralysis', 1149),
#  ('iii', 1148),
#  ('nausea', 1148),
#  ('duct', 1146),
#  ('possibly', 1146),
#  ('rest', 1144),
#  ('delay', 1144),
#  ('field', 1144),
#  ('member', 1143),
#  ('daily', 1142),
#  ('breathing|breathe', 1141),
#  ('behavioral', 1139),
#  ('2010', 1139),
#  ('intestinal', 1138),
#  ...]

# %%
with open('counter_Tokens.p', 'rb') as f:
        count = pickle.load(f)

# %%
print(len(count))
count.most_common()
# Out:
# 166557
# [('the', 471282),
#  ('of', 339325),
#  ('and', 246131),
#  ('in', 213046),
#  ('to', 193973),
#  ('a', 177881),
#  ('is', 165293),
#  ('with', 96718),
#  ('or', 87206),
#  ('as', 77064),
#  ('are', 74482),
#  ('be', 70263),
#  ('that', 66381),
#  ('for', 66162),
#  ('by', 54350),
#  ('may', 51461),
#  ('it', 47210),
#  ('can', 44736),
#  ('an', 40650),
#  ('this', 39477),
#  ('have', 38132),
#  ('on', 37736),
#  ('from', 36484),
#  ('not', 35478),
#  ('which', 30190),
#  ('disease', 29096),
#  ('also', 28927),
#  ('%', 27524),
#  ('has', 25094),
#  ('at', 24235),
#  ('other', 24070),
#  ('symptoms', 23123),
#  ("'s", 23007),
#  ('been', 22910),
#  ('syndrome', 22786),
#  ('such', 22323),
#  ('more', 21836),
#  ('was', 21145),
#  ('but', 20914),
#  ('treatment', 20401),
#  ('most', 19392),
#  ('there', 19351),
#  ('patients', 18656),
#  ('blood', 18005),
#  ('these', 17900),
#  ('–', 17690),
#  ('than', 17261),
#  ('people', 17195),
#  ('cases', 17138),
#  ('some', 16997),
#  ('cause', 16878),
#  ('if', 16429),
#  ('one', 16216),
#  ('when', 15409),
#  ('include', 15396),
#  ('they', 14987),
#  ('often', 14337),
#  ('common', 14071),
#  ('used', 13763),
#  ('disorder', 13613),
#  ('their', 13250),
#  ('risk', 13217),
#  ('due', 12987),
#  ('after', 12913),
#  ('who', 12813),
#  ('associated', 12667),
#  ('no', 12034),
#  ('cells', 11906),
#  ('usually', 11773),
#  ('pain', 11747),
#  ('i', 11664),
#  ('however', 11109),
#  ('diagnosis', 10974),
#  ('condition', 10914),
#  ('type', 10459),
#  ('found', 10309),
#  ('those', 10295),
#  ('use', 10207),
#  ('about', 10180),
#  ('all', 10044),
#  ('into', 9771),
#  ('during', 9691),
#  ('were', 9691),
#  ('cancer', 9675),
#  ('children', 9586),
#  ('first', 9567),
#  ('between', 9513),
#  ('skin', 9498),
#  ('known', 9444),
#  ('occur', 9374),
#  ('caused', 9323),
#  ('1', 9297),
#  ('infection', 9218),
#  ('will', 9105),
#  ('only', 9097),
#  ('many', 8761),
#  ('causes', 8750),
#  ('two', 8707),
#  ('should', 8659),
#  ('brain', 8541),
#  ('severe', 8512),
#  ('&', 8500),
#  ('disorders', 8463),
#  ('result', 8274),
#  ('cell', 8265),
#  ('both', 8227),
#  ('normal', 8095),
#  ('high', 8031),
#  ('body', 7860),
#  ('affected', 7810),
#  ('loss', 7783),
#  ('while', 7778),
#  ('increased', 7753),
#  ('therapy', 7699),
#  ('do', 7694),
#  ('gene', 7664),
#  ('heart', 7606),
#  ('utc', 7599),
#  ('because', 7583),
#  ('its', 7574),
#  ('including', 7537),
#  ('any', 7492),
#  ('present', 7453),
#  ('age', 7444),
#  ('years', 7402),
#  ('time', 7338),
#  ('2', 7200),
#  ('clinical', 7044),
#  ('occurs', 7013),
#  ('levels', 6952),
#  ('individuals', 6921),
#  ('surgery', 6903),
#  ('patient', 6894),
#  ('form', 6866),
#  ("'", 6731),
#  ('less', 6628),
#  ('typically', 6608),
#  ('medical', 6567),
#  ('through', 6519),
#  ('over', 6419),
#  ('women', 6419),
#  ('system', 6395),
#  ('person', 6385),
#  ('chronic', 6380),
#  ('well', 6330),
#  ('=', 6270),
#  ('being', 6265),
#  ('tissue', 6251),
#  ('where', 6185),
#  ('within', 6167),
#  ('studies', 6131),
#  ('had', 6058),
#  ('low', 5995),
#  ('bone', 5936),
#  ('although', 5908),
#  ('muscle', 5883),
#  ('study', 5882),
#  ('reported', 5838),
#  ('factors', 5788),
#  ('conditions', 5787),
#  ('commonly', 5757),
#  ('small', 5723),
#  ('early', 5719),
#  ('genetic', 5559),
#  ('3', 5541),
#  ('without', 5515),
#  ('health', 5485),
#  ('rare', 5484),
#  ('pressure', 5469),
#  ('evidence', 5448),
#  ('up', 5405),
#  ('diseases', 5350),
#  ('very', 5316),
#  ('injury', 5297),
#  ('development', 5226),
#  ('10', 5215),
#  ('acute', 5211),
#  ('results', 5197),
#  ('does', 5190),
#  ('lead', 5098),
#  ('different', 5052),
#  ('damage', 5016),
#  ('number', 5016),
#  ('mutations', 5011),
#  ('called', 4940),
#  ('seen', 4935),
#  ('rate', 4927),
#  ('problems', 4914),
#  ('several', 4904),
#  ('protein', 4876),
#  ('so', 4837),
#  ('tumor', 4783),
#  ('effects', 4764),
#  ('case', 4761),
#  ('specific', 4735),
#  ('you', 4723),
#  ('new', 4704),
#  ('even', 4702),
#  ('deficiency', 4653),
#  ('described', 4631),
#  ('following', 4594),
#  ('generally', 4587),
#  ('liver', 4578),
#  ('similar', 4577),
#  ('three', 4532),
#  ('then', 4518),
#  ('out', 4504),
#  ('function', 4485),
#  ('increase', 4483),
#  ('sometimes', 4453),
#  ('develop', 4449),
#  ('research', 4412),
#  ('death', 4409),
#  ('nerve', 4399),
#  ('physical', 4387),
#  ('using', 4385),
#  ('before', 4337),
#  ('another', 4327),
#  ('test', 4324),
#  ('primary', 4313),
#  ('likely', 4307),
#  ('changes', 4267),
#  ('types', 4255),
#  ('would', 4254),
#  ('possible', 4205),
#  ('infections', 4202),
#  ('000', 4168),
#  ('effective', 4160),
#  ('large', 4145),
#  ('5', 4135),
#  ('either', 4127),
#  ('lower', 4121),
#  ('signs', 4117),
#  ('states', 4116),
#  ('sleep', 4109),
#  ('considered', 4106),
#  ('life', 4100),
#  ('based', 4097),
#  ('term', 4079),
#  ('like', 4067),
#  ('diagnosed', 3990),
#  ('higher', 3976),
#  ('20', 3967),
#  ('lesions', 3966),
#  ('failure', 3935),
#  ('since', 3929),
#  ('among', 3919),
#  ('shown', 3904),
#  ('treated', 3882),
#  ('eye', 3874),
#  ('multiple', 3851),
#  ('part', 3846),
#  ('months', 3829),
#  ('virus', 3820),
#  ('related', 3811),
#  ('drug', 3791),
#  ('lung', 3789),
#  ('drugs', 3778),
#  ('could', 3763),
#  ('same', 3756),
#  ('characterized', 3754),
#  ('per', 3732),
#  ('around', 3717),
#  ('recommended', 3716),
#  ('kidney', 3700),
#  ('help', 3698),
#  ('them', 3687),
#  ('fever', 3671),
#  ('4', 3668),
#  ('exposure', 3665),
#  ('control', 3655),
#  ('b', 3652),
#  ('human', 3649),
#  ('pregnancy', 3645),
#  ('history', 3632),
#  ('response', 3605),
#  ('growth', 3595),
#  ('surgical', 3590),
#  ('abnormal', 3587),
#  ('inflammation', 3584),
#  ('certain', 3576),
#  ('further', 3555),
#  ('under', 3553),
#  ('—', 3548),
#  ('united', 3530),
#  ('presence', 3526),
#  ('tumors', 3524),
#  ('tests', 3523),
#  ('medications', 3515),
#  ('|', 3501),
#  ('child', 3498),
#  ('made', 3495),
#  ('areas', 3494),
#  ('e.g.', 3492),
#  ('especially', 3490),
#  ('important', 3474),
#  ('mutation', 3439),
#  ('general', 3426),
#  ('replaced-url', 3426),
#  ('example', 3416),
#  ('individual', 3343),
#  ('birth', 3339),
#  ('congenital', 3329),
#  ('onset', 3305),
#  ('significant', 3293),
#  ('year', 3290),
#  ('complications', 3283),
#  ('weeks', 3276),
#  ('side', 3267),
#  ('area', 3241),
#  ('adults', 3240),
#  ('show', 3229),
#  ('head', 3227),
#  ('2019', 3220),
#  ('left', 3214),
#  ('become', 3210),
#  ('factor', 3199),
#  ('fluid', 3190),
#  ('c', 3188),
#  ('days', 3185),
#  ('family', 3184),
#  ("n't", 3181),
#  ('causing', 3178),
#  ('long', 3175),
#  ('activity', 3173),
#  ('treatments', 3172),
#  ('replaced-dns', 3165),
#  ('6', 3154),
#  ('level', 3147),
#  ('2017', 3147),
#  ('see', 3134),
#  ('trauma', 3124),
#  ('appear', 3120),
#  ('his', 3119),
#  ('oral', 3106),
#  ('15', 3100),
#  ('bleeding', 3097),
#  ('rates', 3089),
#  ('pulmonary', 3087),
#  ('abnormalities', 3086),
#  ('experience', 3067),
#  ('what', 3060),
#  ('world', 3056),
#  ('50', 3050),
#  ('reduce', 3046),
#  ('features', 3041),
#  ('effect', 3036),
#  ('still', 3030),
#  ('each', 3026),
#  ('acid', 3021),
#  ('involved', 3021),
#  ('testing', 3018),
#  ('group', 2993),
#  ('least', 2985),
#  ('few', 2970),
#  ('though', 2963),
#  ('diagnostic', 2960),
#  ('alcohol', 2955),
#  ('30', 2950),
#  ('forms', 2941),
#  ('lack', 2913),
#  ('prevent', 2909),
#  ('much', 2902),
#  ('#', 2897),
#  ('stage', 2878),
#  ('immune', 2877),
#  ('resulting', 2873),
#  ('major', 2869),
#  ('care', 2854),
#  ('diabetes', 2851),
#  ('joint', 2847),
#  ('j', 2839),
#  ('food', 2828),
#  ('thought', 2825),
#  ('others', 2813),
#  ('population', 2790),
#  ('men', 2772),
#  ('mental', 2766),
#  ('right', 2766),
#  ('t', 2766),
#  ('decreased', 2766),
#  ('central', 2765),
#  ('et', 2764),
#  ('12', 2764),
#  ('reduced', 2762),
#  ('february', 2752),
#  ('genes', 2744),
#  ('underlying', 2741),
#  ('having', 2733),
#  ('leading', 2732),
#  ('american', 2718),
#  ('infected', 2712),
#  ('identified', 2709),
#  ('back', 2703),
#  ('various', 2698),
#  ('he', 2696),
#  ('page', 2689),
#  ('autosomal', 2688),
#  ('poor', 2675),
#  ('given', 2673),
#  ('water', 2664),
#  ('affect', 2658),
#  ('incidence', 2650),
#  ('spinal', 2642),
#  ('developing', 2642),
#  ('m', 2641),
#  ('particularly', 2638),
#  ('need', 2634),
#  ('chest', 2633),
#  ('social', 2629),
#  ('process', 2625),
#  ('weight', 2624),
#  ('involves', 2623),
#  ('thus', 2618),
#  ('muscles', 2609),
#  ('abdominal', 2600),
#  ('stress', 2593),
#  ('chromosome', 2586),
#  ('later', 2586),
#  ('secondary', 2585),
#  ('affects', 2585),
#  ('whether', 2581),
#  ('red', 2565),
#  ('severity', 2562),
#  ('mild', 2560),
#  ('against', 2548),
#  ('required', 2546),
#  ('greater', 2543),
#  ('therefore', 2539),
#  ('must', 2537),
#  ('imaging', 2519),
#  ('performed', 2518),
#  ('criteria', 2505),
#  ('association', 2500),
#  ('respiratory', 2488),
#  ('frequently', 2482),
#  ('how', 2475),
#  ('sexual', 2472),
#  ('difficult', 2472),
#  ('work', 2469),
#  ('approximately', 2441),
#  ('available', 2439),
#  ('depression', 2426),
#  ('support', 2417),
#  ('seizures', 2410),
#  ('al.', 2404),
#  ('addition', 2398),
#  ('make', 2392),
#  ('medicine', 2373),
#  ('examination', 2372),
#  ('role', 2359),
#  ('white', 2357),
#  ('upper', 2355),
#  ('motor', 2352),
#  ('cardiac', 2335),
#  ('management', 2326),
#  ('survival', 2317),
#  ('positive', 2312),
#  ('done', 2309),
#  ('cutaneous', 2300),
#  ('males', 2294),
#  ('treat', 2292),
#  ('anxiety', 2291),
#  ('developed', 2288),
#  ('medication', 2280),
#  ('25', 2280),
#  ('list', 2279),
#  ('100', 2269),
#  ('range', 2267),
#  ('urine', 2260),
#  ('hours', 2254),
#  ('information', 2245),
#  ('four', 2244),
#  ('artery', 2242),
#  ('above', 2242),
#  ('i.e.', 2241),
#  ('carcinoma', 2236),
#  ('d', 2228),
#  ('prevalence', 2220),
#  ('hearing', 2219),
#  ('countries', 2215),
#  ('second', 2212),
#  ('lesion', 2211),
#  ('until', 2201),
#  ('require', 2195),
#  ('article', 2194),
#  ('ability', 2189),
#  ('tract', 2188),
#  ('bacteria', 2188),
#  ('period', 2188),
#  ('dysfunction', 2187),
#  ('main', 2187),
#  ('inflammatory', 2185),
#  ('flow', 2184),
#  ('includes', 2184),
#  ('sign', 2182),
#  ('potential', 2181),
#  ('production', 2177),
#  ('spread', 2175),
#  ('just', 2173),
#  ('oxygen', 2171),
#  ('appears', 2166),
#  ('neck', 2163),
#  ('visual', 2161),
#  ('times', 2161),
#  ('leads', 2159),
#  ('tissues', 2146),
#  ('size', 2144),
#  ('now', 2144),
#  ('compared', 2143),
#  ('neurological', 2130),
#  ('complete', 2128),
#  ('increases', 2126),
#  ('rather', 2117),
#  ('unknown', 2112),
#  ('childhood', 2110),
#  ('movement', 2106),
#  ('estimated', 2099),
#  ('anemia', 2096),
#  ('young', 2094),
#  ('might', 2089),
#  ('day', 2089),
#  ('review', 2086),
#  ('nervous', 2082),
#  ('mouth', 2082),
#  ('humans', 2081),
#  ('observed', 2081),
#  ('state', 2073),
#  ('antibiotics', 2072),
#  ('combination', 2070),
#  ('improve', 2067),
#  ('contact', 2064),
#  ('proteins', 2063),
#  ('down', 2061),
#  ('cerebral', 2055),
#  ('way', 2054),
#  ('recent', 2053),
#  ('ct', 2052),
#  ('hair', 2049),
#  ('short', 2048),
#  ('systemic', 2043),
#  ('fracture', 2043),
#  ('elevated', 2042),
#  ('findings', 2032),
#  ('infants', 2031),
#  ('limited', 2022),
#  ('7', 2020),
#  ('breast', 2018),
#  ('vessels', 2014),
#  ('better', 2010),
#  ('decrease', 2010),
#  ('18', 2007),
#  ('initial', 2003),
#  ('single', 2001),
#  ('vitamin', 1992),
#  ('excessive', 1988),
#  ('report', 1988),
#  ('problem', 1987),
#  ('appearance', 1987),
#  ('cannot', 1986),
#  ('change', 1983),
#  ('females', 1983),
#  ('40', 1982),
#  ('useful', 1982),
#  ('speech', 1981),
#  ('injuries', 1978),
#  ('rarely', 1978),
#  ('suggested', 1973),
#  ('8', 1972),
#  ('vision', 1971),
#  ('renal', 1970),
#  ('did', 1968),
#  ('normally', 1965),
#  ('cord', 1964),
#  ('l', 1958),
#  ('formation', 1958),
#  ('ii', 1952),
#  ('mri', 1945),
#  ('million', 1942),
#  ('according', 1942),
#  ('symptom', 1933),
#  ('hormone', 1933),
#  ('national', 1932),
#  ('prognosis', 1925),
#  ('illness', 1924),
#  ('thyroid', 1908),
#  ('2018', 1906),
#  ('teeth', 1900),
#  ('defects', 1897),
#  ('january', 1894),
#  ('behavior', 1890),
#  ('radiation', 1888),
#  ('14', 1886),
#  ('produce', 1884),
#  ('complex', 1874),
#  ('e', 1873),
#  ('weakness', 1873),
#  ('needed', 1867),
#  ('cognitive', 1864),
#  ('antibodies', 1856),
#  ('necessary', 1856),
#  ('malignant', 1853),
#  ('along', 1852),
#  ('chemotherapy', 1849),
#  ('stroke', 1845),
#  ('mortality', 1845),
#  ('via', 1844),
#  ('mechanism', 1843),
#  ('once', 1842),
#  ('below', 1828),
#  ('deaths', 1826),
#  ('order', 1824),
#  ('negative', 1823),
#  ('long-term', 1818),
#  ('recessive', 1809),
#  ('good', 1809),
#  ('procedure', 1807),
#  ('eyes', 1795),
#  ('region', 1793),
#  ('last', 1792),
#  ('peripheral', 1791),
#  ('longer', 1788),
#  ('depending', 1788),
#  ('current', 1786),
#  ('swelling', 1786),
#  ('pattern', 1782),
#  ('2016', 1780),
#  ('currently', 1780),
#  ('prevention', 1778),
#  ('point', 1777),
#  ('hypertension', 1774),
#  ('facial', 1766),
#  ('serious', 1766),
#  ('name', 1765),
#  ('ear', 1763),
#  ('inherited', 1763),
#  ('classification', 1762),
#  ('us', 1761),
#  ('hand', 1760),
#  ('amount', 1757),
#  ('personality', 1756),
#  ('16', 1753),
#  ('able', 1752),
#  ('biopsy', 1752),
#  ('particular', 1749),
#  ('dna', 1748),
#  ('her', 1747),
#  ('classified', 1744),
#  ('benign', 1742),
#  ('exercise', 1742),
#  ('percent', 1740),
#  ('reaction', 1736),
#  ('difficulty', 1733),
#  ('autoimmune', 1731),
#  ('enzyme', 1719),
#  ('older', 1712),
#  ('light', 1712),
#  ('absence', 1707),
#  ('referred', 1706),
#  ('surface', 1706),
#  ('vomiting', 1696),
#  ('11', 1696),
#  ('arthritis', 1692),
#  ('itself', 1687),
#  ('followed', 1684),
#  ('language', 1682),
#  ('calcium', 1679),
#  ('bowel', 1677),
#  ('24', 1672),
#  ('we', 1672),
#  ('means', 1669),
#  ('female', 1664),
#  ('appropriate', 1659),
#  ('lymphoma', 1653),
#  ('male', 1650),
#  ('published', 1650),
#  ('adult', 1645),
#  ('method', 1644),
#  ('five', 1642),
#  ('bacterial', 1639),
#  ('ultrasound', 1638),
#  ('species', 1635),
#  ('eating', 1634),
#  ('receptor', 1634),
#  ('additional', 1634),
#  ('hospital', 1633),
#  ('little', 1631),
#  ('take', 1631),
#  ('clear', 1628),
#  ('determine', 1626),
#  ('diet', 1620),
#  ('face', 1619),
#  ('responsible', 1618),
#  ('defined', 1615),
#  ('tooth', 1613),
#  ('lungs', 1611),
#  ('h', 1609),
#  ('abuse', 1607),
#  ('progressive', 1603),
#  ('lymph', 1599),
#  ('march', 1598),
#  ('wall', 1597),
#  ('serum', 1595),
#  ('breathing', 1595),
#  ('reduction', 1594),
#  ('enough', 1593),
#  ('anterior', 1589),
#  ('viral', 1589),
#  ('vascular', 1588),
#  ('believed', 1583),
#  ('proposed', 1582),
#  ('--', 1581),
#  ('impairment', 1579),
#  ('linked', 1579),
#  ('total', 1578),
#  ('removal', 1577),
#  ('s', 1572),
#  ('dominant', 1567),
#  ('increasing', 1566),
#  ('involve', 1566),
#  ('13', 1566),
#  ('located', 1561),
#  ('direct', 1556),
#  ('fractures', 1554),
#  ('sex', 1551),
#  ('half', 1550),
#  ('21', 1547),
#  ('functional', 1546),
#  ('relatively', 1545),
#  ('22', 1541),
#  ('september', 1538),
#  ('cancers', 1536),
#  ('every', 1531),
#  ('site', 1524),
#  ('screening', 1524),
#  ('third', 1523),
#  ('typical', 1523),
#  ('provide', 1521),
#  ('too', 1520),
#  ('defect', 1518),
#  ('discussion', 1517),
#  ('17', 1511),
#  ('characteristic', 1510),
#  ('overall', 1510),
#  ('taken', 1505),
#  ('involvement', 1501),
#  ('p.', 1500),
#  ('frequent', 1497),
#  ('removed', 1497),
#  ('19', 1496),
#  ('active', 1494),
#  ('obstruction', 1493),
#  ('posterior', 1493),
#  ('membrane', 1493),
#  ('suggest', 1493),
#  ('almost', 1489),
#  ('phase', 1486),
#  ('memory', 1485),
#  ('healthy', 1485),
#  ('specifically', 1483),
#  ('quality', 1479),
#  ('simple', 1477),
#  ('impaired', 1477),
#  ('data', 1473),
#  ('template', 1470),
#  ('parts', 1467),
#  ('r', 1465),
#  ('get', 1463),
#  ('involving', 1462),
#  ('headache', 1461),
#  ('groups', 1461),
#  ('developmental', 1460),
#  ('old', 1460),
#  ('gastrointestinal', 1459),
#  ('organs', 1458),
#  ('volume', 1457),
#  ('suspected', 1457),
#  ('iron', 1455),
#  ('urinary', 1453),
#  ('benefit', 1451),
#  ('journal', 1450),
#  ('rapid', 1449),
#  ('standard', 1449),
#  ('bladder', 1448),
#  ('90', 1448),
#  ('my', 1447),
#  ('cysts', 1444),
#  ('methods', 1441),
#  ('pneumonia', 1440),
#  ('significantly', 1440),
#  ('psychological', 1437),
#  ('degree', 1437),
#  ('metabolic', 1435),
#  ('60', 1434),
#  ('researchers', 1434),
#  ('9', 1433),
#  ('source', 1433),
#  ('course', 1430),
#  ('making', 1430),
#  ('local', 1429),
#  ('episodes', 1427),
#  ('bones', 1426),
#  ('agents', 1419),
#  ('upon', 1418),
#  ('occurring', 1414),
#  ('mass', 1410),
#  ('requires', 1409),
#  ('ventricular', 1408),
#  ('remains', 1407),
#  ('dental', 1406),
#  ('six', 1404),
#  ('yet', 1404),
#  ('recurrent', 1400),
#  ('majority', 1400),
#  ('glucose', 1399),
#  ('best', 1398),
#  ('g', 1393),
#  ('always', 1391),
#  ('position', 1390),
#  ('aortic', 1389),
#  ('suggests', 1384),
#  ('showed', 1382),
#  ('outcomes', 1380),
#  ('prior', 1378),
#  ('your', 1372),
#  ('own', 1367),
#  ('prolonged', 1366),
#  ('late', 1366),
#  ('plasma', 1364),
#  ('despite', 1364),
#  ('shows', 1363),
#  ('vary', 1362),
#  ('confirmed', 1360),
#  ('tend', 1358),
#  ('average', 1356),
#  ('primarily', 1355),
#  ('frequency', 1354),
#  ('location', 1354),
#  ('parents', 1351),
#  ('fetal', 1350),
#  ('leukemia', 1349),
#  ('highly', 1349),
#  ('air', 1348),
#  ('mg', 1346),
#  ('infectious', 1345),
#  ('80', 1344),
#  ('progression', 1338),
#  ('image', 1338),
#  ('23', 1335),
#  ('cervical', 1333),
#  ('treating', 1332),
#  ('named', 1331),
#  ('wikipedia', 1330),
#  ('stomach', 1328),
#  ('hepatitis', 1327),
#  ('instead', 1327),
#  ('smoking', 1322),
#  ('sensitivity', 1318),
#  ('marrow', 1318),
#  ('psychiatric', 1318),
#  ('ed', 1316),
#  ('movements', 1312),
#  ('internal', 1312),
#  ('diarrhea', 1311),
#  ('s.', 1309),
#  ('approach', 1308),
#  ('“', 1307),
#  ('attacks', 1306),
#  ('”', 1306),
#  ('recovery', 1303),
#  ('analysis', 1301),
#  ('techniques', 1299),
#  ('cyst', 1296),
#  ('disability', 1296),
#  ('becomes', 1296),
#  ('foot', 1292),
#  ('directly', 1290),
#  ('end', 1289),
#  ('edema', 1287),
#  ('external', 1285),
#  ('expression', 1285),
#  ('epilepsy', 1280),
#  ('open', 1280),
#  ('place', 1273),
#  ('resistance', 1272),
#  ('2013', 1270),
#  ('release', 1269),
#  ('unclear', 1265),
#  ('occasionally', 1260),
#  ('gland', 1258),
#  ('mother', 1258),
#  ('avoid', 1258),
#  ('sensory', 1256),
#  ('block', 1254),
#  ('baby', 1254),
#  ('fear', 1251),
#  ('2015', 1251),
#  ('fatigue', 1249),
#  ('international', 1245),
#  ('alone', 1244),
#  ('subsequent', 1244),
#  ('here', 1244),
#  ('university', 1242),
#  ('animals', 1242),
#  ('occurred', 1242),
#  ('vaccine', 1241),
#  ('acquired', 1239),
#  ('presentation', 1239),
#  ('insulin', 1239),
#  ('space', 1236),
#  ('asymptomatic', 1235),
#  ('painful', 1235),
#  ('variety', 1234),
#  ('knee', 1229),
#  ('produced', 1229),
#  ('affecting', 1227),
#  ('stages', 1219),
#  ('transmission', 1216),
#  ('persons', 1214),
#  ('syndromes', 1213),
#  ('moderate', 1210),
#  ('shock', 1208),
#  ('nasal', 1207),
#  ('public', 1205),
#  ('terms', 1204),
#  ('excess', 1202),
#  ('meaning', 1200),
#  ('intervention', 1198),
#  ('mechanisms', 1197),
#  ('atrophy', 1195),
#  ('refers', 1195),
#  ('presents', 1195),
#  ('reports', 1194),
#  ('distal', 1192),
#  ('regions', 1192),
#  ('trials', 1190),
#  ('together', 1187),
#  ('arm', 1187),
#  ('close', 1186),
#  ('partial', 1184),
#  ('environmental', 1184),
#  ('u.s.', 1182),
#  ('ovarian', 1181),
#  ('characteristics', 1177),
#  ('advanced', 1176),
#  ('scan', 1176),
#  ('activities', 1175),
#  ('indicated', 1175),
#  ('sudden', 1174),
#  ('cold', 1169),
#  ('k', 1169),
#  ('fat', 1168),
#  ('emotional', 1165),
#  ('full', 1165),
#  ('previously', 1164),
#  ('fact', 1163),
#  ('hereditary', 1161),
#  ('obesity', 1160),
#  ('link', 1160),
#  ('middle', 1158),
#  ('action', 1158),
#  ('lateral', 1157),
#  ('repair', 1156),
#  ('dementia', 1156),
#  ('identify', 1155),
#  ('mainly', 1155),
#  ('70', 1154),
#  ('structures', 1153),
#  ('section', 1153),
#  ('hiv', 1152),
#  ('nature', 1152),
#  ('poisoning', 1151),
#  ('iii', 1148),
#  ('nausea', 1148),
#  ('free', 1147),
#  ('possibly', 1146),
#  ('born', 1146),
#  ('paralysis', 1145),
#  ('limb', 1145),
#  ('reason', 1144),
#  ('organ', 1143),
#  ('daily', 1142),
#  ('contrast', 1142),
#  ('find', 1141),
#  ('soft', 1140),
#  ('nodes', 1140),
#  ('behavioral', 1139),
#  ('2010', 1139),
#  ('intestinal', 1138),
#  ('reducing', 1138),
#  ('2005', 1137),
#  ('attention', 1136),
#  ('stenosis', 1136),
#  ('completely', 1136),
#  ('issues', 1136),
#  ('laboratory', 1136),
#  ('detected', 1135),
#  ('venous', 1133),
#  ('intravenous', 1132),
#  ('measures', 1132),
#  ...]

# %%
count.keys()
# Out:
# dict_keys(['autism', 'motor', 'neuron', 'disease', 'acute', 'disseminated', 'encephalomyelitis', 'ataxia', 'abscess', 'arachnophobia', 'arthritis', 'aphasia', 'albinism', 'in', 'humans', 'alcoholism', 'amputation', 'arteriovenous', 'malformation', 'brain', 'bipolar', 'disorder', 'bacterial', 'vaginosis', 'plague', 'i', 'catatonia', 'creutzfeldt', '–', 'jakob', 'coma', 'bradycardia', 'coronary', 'artery', 'congenital', 'iodine', 'deficiency', 'syndrome', 'chagas', 'chlamydia', 'candidiasis', 'color', 'blindness', 'cholera', 'cerebral', 'charcot', 'marie', 'tooth', 'central', 'pontine', 'myelinolysis', 'alcohol', 'intoxication', 'down', 'dyslexia', 'major', 'depressive', 'endocarditis', 'expressive', 'epilepsy', 'essential', 'tremor', 'fugue', 'state', 'flatulence', 'foix', 'alajouanine', 'goitre', 'genetic', 'hypoxia', 'medical', 'hypoglycemia', 'hyperthyroidism', 'hemiparesis', 'haemophilia', 'erectile', 'dysfunction', 'interstitial', 'cystitis', 'inhalant', 'inclusion', 'body', 'myositis', 'kwashiorkor', 'kocher', 'debre', 'semelaigne', 'lassa', 'fever', 'lung', 'cancer', 'leukemia', 'lambert', 'eaton', 'myasthenic', 'lymphedema', 'muscular', 'dystrophy', 'myasthenia', 'gravis', 'mental', 'mania', 'malaria', 'meconium', 'aspiration', 'migraine', 'neuromyotonia', 'nitrogen', 'narcosis', 'osteoporosis', 'optic', 'neuritis', 'prion', 'phenylketonuria', 'paralysis', 'phobia', 'paroxysmal', 'attack', 'paraphilia', 'pain', 'psychosis', 'paranoia', 'pelvic', 'inflammatory', 'autosomal', 'dominant', 'polycystic', 'kidney', 'polio', 'progressive', 'multifocal', 'leukoencephalopathy', 'idiopathic', 'intracranial', 'hypertension', 'repetitive', 'strain', 'injury', 'rheumatoid', 'rickets', 'receptive', 'rift', 'valley', 'ramsay', 'hunt', 'type', '2', 'systemic', 'scleroderma', 'epileptic', 'seizure', 'schizophrenia', 'scurvy', 'stuttering', 'sleep', 'apnea', 'sinusitis', 'stevens', 'johnson', 'scabies', 'syphilis', 'serotonin', 'syringomyelia', 'renal', 'dysplasia-limb', 'defects', 'umbilical', 'cord', 'ulceration', 'and', 'intestinal', 'atresia', 'brown-séquard', 'fructosuria', 'uncombable', 'hair', 'upington', 'urban', 'rogers', 'meyer', 'galactose-1-phosphate', 'uridylyltransferase', 'thallium', 'poisoning', 'angor', 'animi', 'levine', "'s", 'sign', 'usual', 'pneumonia', 'caffeine-induced', 'lower', 'lesion', 'angioimmunoblastic', 't-cell', 'lymphoma', 'histiocytosis', 'mesenteric', 'ischemia', 'diastematomyelia', 'complement', 'diastasis', 'recti', 'spasmodic', 'dysphonia', 'parametritis', 'choledochal', 'cysts', 'neck', 'atypical', 'teratoid', 'rhabdoid', 'tumor', 'conjugate', 'gaze', 'palsy', 'epiphora', 'medicine', 'quadrantanopia', 'anopsia', 'juvenile', 'myelomonocytic', 'allan', 'herndon', 'dudley', 'tetrasomy', '18p', 'acrodermatitis', 'chronica', 'atrophicans', 'cœur', 'en', 'sabot', 'senile', 'ulnar', 'nerve', 'entrapment', 'hypohidrosis', 'pituicytoma', 'frailty', 'orotic', 'aciduria', 'generalized', 'tonic', 'clonic', 'pappataci', 'blood', 'haphephobia', 'extensively', 'drug-resistant', 'tuberculosis', 'multi-drug-resistant', 'contractural', 'arachnodactyly', 'cephalopelvic', 'disproportion', 'gestational', 'pemphigoid', 'fourth', 'tinea', 'faciei', 'cat', 'eye', 'glut1', 'stress', 'ulcer', 'adenocarcinoma', 'situ', 'of', 'the', 'endometrial', 'hyperplasia', 'mild', 'cognitive', 'impairment', 'brown', 'biotin', 'adenoiditis', 'cystathioninuria', 'guttate', 'hypomelanosis', 'pulmonary', 'talcosis', 'hand', 'schüller', 'christian', 'handigodu', 'paraneoplastic', 'vertebral', 'compression', 'fracture', 'cornelia', 'de', 'lange', 'adrenal', 'speech', 'sound', 'vaginal', 'hypoplasia', 'complex', 'partial', 'status', 'epilepticus', 'medullary', 'carcinoma', 'monckeberg', 'arteriosclerosis', 'le', 'fort', 'skull', 'sopite', 'pel', 'ebstein', 'cystadenocarcinoma', 'riedel', 'thyroiditis', 'feingold', 'bouchard', 'aneurysm', 'cor', 'bovinum', 'adrenocortical', 'adenoma', 'autophony', 'oculomotor', 'medial', 'lateral', 'heterophoria ...
